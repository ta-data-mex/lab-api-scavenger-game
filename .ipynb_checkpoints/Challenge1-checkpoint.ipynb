# %%
#9c63bbf7df01344414a0a3788077a89550a688ae
#curl -u Patcm10:9c63bbf7df01344414a0a3788077a89550a688ae https://api.github.com/user > output.json

# %%
#curl -u Patcm10:9c63bbf7df01344414a0a3788077a89550a688ae https://api.github.com/user > output.json

# %%
import pandas as pd
import json
from pandas.io.json import json_normalize
import requests
data_git = requests.get('https://api.github.com/repos/ironhack-datalabs/mad-oct-2018')
data_git = data_git.json()
data_git
# Out:
# {'id': 153720804,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=',
#  'name': 'mad-oct-2018',
#  'full_name': 'ironhack-datalabs/mad-oct-2018',
#  'private': False,
#  'owner': {'login': 'ironhack-datalabs',
#   'id': 44225188,
#   'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#   'avatar_url': 'https://avatars2.githubusercontent.com/u/44225188?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ironhack-datalabs',
#   'html_url': 'https://github.com/ironhack-datalabs',
#   'followers_url': 'https://api.github.com/users/ironhack-datalabs/followers',
#   'following_url': 'https://api.github.com/users/ironhack-datalabs/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/ironhack-datalabs/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/ironhack-datalabs/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/ironhack-datalabs/subscriptions',
# ...

# %%
df = pd.DataFrame(data_git)
df
# Out:
#                             id                           node_id  \
# archive_url          153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# archived             153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# assignees_url        153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# avatar_url           153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# blobs_url            153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# branches_url         153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# clone_url            153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# collaborators_url    153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# comments_url         153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# commits_url          153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# compare_url          153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# contents_url         153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# contributors_url     153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# ...

# %%
# Request forks
forks = requests.get('https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/forks')
forks = forks.json()
forks
# Out:
# [{'id': 193946632,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxOTM5NDY2MzI=',
#   'name': 'mad-oct-2018',
#   'full_name': 'aiborra11/mad-oct-2018',
#   'private': False,
#   'owner': {'login': 'aiborra11',
#    'id': 48259489,
#    'node_id': 'MDQ6VXNlcjQ4MjU5NDg5',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/48259489?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aiborra11',
#    'html_url': 'https://github.com/aiborra11',
#    'followers_url': 'https://api.github.com/users/aiborra11/followers',
#    'following_url': 'https://api.github.com/users/aiborra11/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/aiborra11/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/aiborra11/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/aiborra11/subscriptions',
#    'organizations_url': 'https://api.github.com/users/aiborra11/orgs',
# ...

# %%
# Obtener lenguajes
f = pd.DataFrame(forks)
list(set(f['language']))
# Out:
# ['Python', 'Jupyter Notebook', 'HTML']

# %%
# Número Lenguajes 
languages = requests.get('https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/languages')
languages = languages.json()
languages
# Out:
# {'Jupyter Notebook': 1134241, 'HTML': 498316, 'Python': 8691}
