# %%
# Challenge 1: Fork Languages --> find out how many programming languages are used among all the forks created
# from the main lab repo of ironhack-datalabs/madrid-oct-2018

# Obtain the full list of forks created from the main lab repo via Github API.
# Loop the JSON response to find out the language attribute of each fork. 
#Use an array to store the language attributes of each fork. Print the language array.

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
data_madrid = requests.get('https://api.github.com/repos/ironhack-datalabs/mad-oct-2018')
data_madrid = data_madrid.json()
data_madrid
# Out:
# {'id': 153720804,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=',
#  'name': 'mad-oct-2018',
#  'full_name': 'ironhack-datalabs/mad-oct-2018',
#  'private': False,
#  'owner': {'login': 'ironhack-datalabs',
#   'id': 44225188,
#   'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#   'avatar_url': 'https://avatars2.githubusercontent.com/u/44225188?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ironhack-datalabs',
#   'html_url': 'https://github.com/ironhack-datalabs',
#   'followers_url': 'https://api.github.com/users/ironhack-datalabs/followers',
#   'following_url': 'https://api.github.com/users/ironhack-datalabs/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/ironhack-datalabs/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/ironhack-datalabs/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/ironhack-datalabs/subscriptions',
# ...

# %%
# De toda la info, solo nos interesan los forks: 
data_madrid_fork = requests.get('https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/forks')
data_madrid_fork = data_madrid_fork.json()
data_madrid_fork
# Out:
# [{'id': 193946632,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxOTM5NDY2MzI=',
#   'name': 'mad-oct-2018',
#   'full_name': 'aiborra11/mad-oct-2018',
#   'private': False,
#   'owner': {'login': 'aiborra11',
#    'id': 48259489,
#    'node_id': 'MDQ6VXNlcjQ4MjU5NDg5',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/48259489?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aiborra11',
#    'html_url': 'https://github.com/aiborra11',
#    'followers_url': 'https://api.github.com/users/aiborra11/followers',
#    'following_url': 'https://api.github.com/users/aiborra11/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/aiborra11/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/aiborra11/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/aiborra11/subscriptions',
#    'organizations_url': 'https://api.github.com/users/aiborra11/orgs',
# ...

# %%
# Lo mismo para los lenguajes:
data_madrid_len = requests.get('https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/languages')
data_madrid_len = data_madrid_len.json()
data_madrid_len
# Out:
# {'Jupyter Notebook': 1134241, 'HTML': 498316, 'Python': 8691}

# %%
# finalmente:
# sabemos qué columna llamar porque la vemos en el archivo json de data_madrid_fork
df = pd.DataFrame(data_madrid_fork)
#df.head()
list(set(df['language']))
# Out:
# ['HTML', 'Jupyter Notebook', 'Python']

# %%
# Challenge 2: Count Commits
# Obtain all the commits made in the past week via API, 
#which is a JSON array that contains multiple commit objects.
# Count how many commit objects are contained in the array.

# %%
data_comm = requests.get('https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/stats/commit_activity')
data_comm = data_comm.json()
data_comm
# Out:
# [{'total': 3, 'week': 1532217600, 'days': [0, 0, 0, 0, 0, 0, 3]},
#  {'total': 1, 'week': 1532822400, 'days': [0, 0, 0, 0, 0, 1, 0]},
#  {'total': 26, 'week': 1533427200, 'days': [0, 1, 1, 19, 2, 3, 0]},
#  {'total': 0, 'week': 1534032000, 'days': [0, 0, 0, 0, 0, 0, 0]},
#  {'total': 9, 'week': 1534636800, 'days': [0, 0, 4, 1, 2, 2, 0]},
#  {'total': 6, 'week': 1535241600, 'days': [0, 3, 0, 2, 1, 0, 0]},
#  {'total': 3, 'week': 1535846400, 'days': [0, 0, 0, 1, 0, 2, 0]},
#  {'total': 7, 'week': 1536451200, 'days': [0, 0, 0, 0, 3, 3, 1]},
#  {'total': 7, 'week': 1537056000, 'days': [0, 0, 1, 1, 5, 0, 0]},
#  {'total': 1, 'week': 1537660800, 'days': [0, 1, 0, 0, 0, 0, 0]},
#  {'total': 7, 'week': 1538265600, 'days': [0, 0, 1, 2, 2, 2, 0]},
#  {'total': 2, 'week': 1538870400, 'days': [0, 1, 0, 1, 0, 0, 0]},
#  {'total': 2, 'week': 1539475200, 'days': [0, 0, 0, 0, 2, 0, 0]},
#  {'total': 29, 'week': 1540080000, 'days': [7, 1, 5, 2, 11, 3, 0]},
# ...

# %%
print("Number of commits: ", data_comm[-1]['total'])
# Out:
# Number of commits:  0

# %%
# Challenge 3: Hidden Cold Joke
# solamente examinar 5 carpetas. 
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the repo:
#https://github.com/ironhack-datalabs/scavenger

# You will need to study the Github API documentation to decide which API endpoint to call 
#and what parameters to use in order to obtain the information you need.

# %%
print("imposible para mí.")
# Out:
# imposible para mí.

# %%
#After you find out the secrete files:
#Sort the filenames ascendingly.
#Read the content of each secret files into an array of strings.
#Concatenate the strings in the array separating each two with a whitespace.
#Print out the joke.
