# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
data = requests.get("https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/")

# %%
data
# Out:
# <Response [404]>

# %%
madrid = data.json()
madrid
# Out:
# {'message': 'Not Found',
#  'documentation_url': 'https://developer.github.com/v3'}

# %%
madrid_repo = pd.DataFrame(madrid)
madrid_repo
# Out:
#                             id                           node_id  \
# archive_url          153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# archived             153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# assignees_url        153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# avatar_url           153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# blobs_url            153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# branches_url         153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# clone_url            153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# collaborators_url    153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# comments_url         153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# commits_url          153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# compare_url          153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# contents_url         153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# contributors_url     153720804  MDEwOlJlcG9zaXRvcnkxNTM3MjA4MDQ=
# ...

# %%
dataf = requests.get("https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/forks")

# %%
dataf
# Out:
# <Response [200]>

# %%
x = list(dataf)

# %%
# Out:
# [b'[{"id":193946632,"node_id":"MDEwOlJlcG9zaXRvcnkxOTM5NDY2MzI=","name":"mad-oct-2018","full_name":"aiborra11/mad-oct-2018","privat',
#  b'e":false,"owner":{"login":"aiborra11","id":48259489,"node_id":"MDQ6VXNlcjQ4MjU5NDg5","avatar_url":"https://avatars0.githubuserco',
#  b'ntent.com/u/48259489?v=4","gravatar_id":"","url":"https://api.github.com/users/aiborra11","html_url":"https://github.com/aiborra',
#  b'11","followers_url":"https://api.github.com/users/aiborra11/followers","following_url":"https://api.github.com/users/aiborra11/f',
#  b'ollowing{/other_user}","gists_url":"https://api.github.com/users/aiborra11/gists{/gist_id}","starred_url":"https://api.github.co',
#  b'm/users/aiborra11/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/aiborra11/subscriptions","organizati',
#  b'ons_url":"https://api.github.com/users/aiborra11/orgs","repos_url":"https://api.github.com/users/aiborra11/repos","events_url":"',
# ...

# %%
datal = requests.get("https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/languages")
datal
# Out:
# <Response [200]>

# %%
datal = datal.json()
datal
# Out:
# {'Jupyter Notebook': 1134241, 'HTML': 498316, 'Python': 8691}

# %%
datal1 = list(datal)
datal1
# Out:
# ['Jupyter Notebook', 'HTML', 'Python']

# %%
datac = requests.get("https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/commits")
datac
# Out:
# <Response [200]>

# %%
data_commits = datac.json()
data_commits
# Out:
# [{'sha': 'f332b5e6fcea965dc80f62220d7ee1457b04b90d',
#   'node_id': 'MDY6Q29tbWl0MTUzNzIwODA0OmYzMzJiNWU2ZmNlYTk2NWRjODBmNjIyMjBkN2VlMTQ1N2IwNGI5MGQ=',
#   'commit': {'author': {'name': 'ta-data-bcn',
#     'email': '47005065+ta-data-bcn@users.noreply.github.com',
#     'date': '2019-03-07T15:49:16Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2019-03-07T15:49:16Z'},
#    'message': 'fix',
#    'tree': {'sha': '74662fcb1b617f9be19739c27c841f9d04532399',
#     'url': 'https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/git/trees/74662fcb1b617f9be19739c27c841f9d04532399'},
#    'url': 'https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/git/commits/f332b5e6fcea965dc80f62220d7ee1457b04b90d',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
# ...

# %%
datacommits = json_normalize(data_commits)
datacommits
# Out:
#                                     author.avatar_url  \
# 0   https://avatars1.githubusercontent.com/u/47005...
# 1   https://avatars1.githubusercontent.com/u/47005...
# 2   https://avatars0.githubusercontent.com/u/12531...
# 3   https://avatars2.githubusercontent.com/u/73428...
# 4   https://avatars2.githubusercontent.com/u/73428...
# 5   https://avatars2.githubusercontent.com/u/73428...
# 6   https://avatars2.githubusercontent.com/u/73428...
# 7   https://avatars3.githubusercontent.com/u/16597...
# 8   https://avatars3.githubusercontent.com/u/16597...
# 9   https://avatars3.githubusercontent.com/u/16597...
# 10  https://avatars2.githubusercontent.com/u/73428...
# 11  https://avatars2.githubusercontent.com/u/73428...
# 12  https://avatars2.githubusercontent.com/u/73428...
# 13  https://avatars2.githubusercontent.com/u/73428...
# 14  https://avatars3.githubusercontent.com/u/16597...
# 15  https://avatars3.githubusercontent.com/u/16597...
# ...

# %%
data_commit = pd.DataFrame(datac)
data_commit
# Out:
#                                                      0
# 0    b'[{"sha":"f332b5e6fcea965dc80f62220d7ee1457b0...
# 1    b'Q1N2IwNGI5MGQ=","commit":{"author":{"name":"...
# 2    b'-07T15:49:16Z"},"committer":{"name":"GitHub"...
# 3    b'{"sha":"74662fcb1b617f9be19739c27c841f9d0453...
# 4    b'4662fcb1b617f9be19739c27c841f9d04532399"},"u...
# 5    b'6fcea965dc80f62220d7ee1457b04b90d","comment_...
# 6    b'P SIGNATURE-----\\n\\nwsBcBAABCAAQBQJcgT18CR...
# 7    b'8PpuPmaT7lCKl8Fn4gDc7q\\nJriGMvxGmP/0BnoZId/...
# 8    b'dGGFYsXr+eUL2TPtLG+doLa4wx\\nL0Oq4NI3HBIEj7J...
# 9    b'GTP7mJHQSGoKEsMO5yAwFHTdGLZ08=\\n=7KZd\\n---...
# 10   b'parent 4c048c3efc18cf9d50e34c76919c8049ee7f2...
# 11   b'0100\\ncommitter GitHub <noreply@github.com>...
# 12   b'-oct-2018/commits/f332b5e6fcea965dc80f62220d...
# 13   b'/f332b5e6fcea965dc80f62220d7ee1457b04b90d","...
# 14   b'332b5e6fcea965dc80f62220d7ee1457b04b90d/comm...
# 15   b',"avatar_url":"https://avatars1.githubuserco...
# ...

# %%
datacommits.head(2)
# Out:
#                                    author.avatar_url  \
# 0  https://avatars1.githubusercontent.com/u/47005...
# 1  https://avatars1.githubusercontent.com/u/47005...
#
#                                    author.events_url  \
# 0  https://api.github.com/users/ta-data-bcn/event...
# 1  https://api.github.com/users/ta-data-bcn/event...
#
#                                 author.followers_url  \
# 0  https://api.github.com/users/ta-data-bcn/follo...
# 1  https://api.github.com/users/ta-data-bcn/follo...
#
#                                 author.following_url  \
# 0  https://api.github.com/users/ta-data-bcn/follo...
# 1  https://api.github.com/users/ta-data-bcn/follo...
#
#                                     author.gists_url author.gravatar_id  \
# 0  https://api.github.com/users/ta-data-bcn/gists...
# 1  https://api.github.com/users/ta-data-bcn/gists...
#
#                   author.html_url  author.id author.login  \
# 0  https://github.com/ta-data-bcn   47005065  ta-data-bcn
# ...

# %%
datacommits = requests.get("https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/stats/commit_activity")
datacommits
# Out:
# <Response [200]>

# %%
datacommits1 = datacommits.json()

# %%
datacommits1[0]
# Out:
# {'total': 3, 'week': 1532217600, 'days': [0, 0, 0, 0, 0, 0, 3]}

# %%
joke = requests.get("https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/master?recursive=1")
joke
#/repos/:owner/:repo/git/trees/:tree_sha?recursive=1
# Out:
# <Response [200]>

# %%
jokes = joke.json()
jokes
# Out:
# {'sha': '9308ccc8a4c34c5e3a991ee815222a9691c32476',
#  'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/9308ccc8a4c34c5e3a991ee815222a9691c32476',
#  'tree': [{'path': '.gitignore',
#    'mode': '100644',
#    'type': 'blob',
#    'sha': 'e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#    'size': 10,
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf'},
#   {'path': '15024',
#    'mode': '040000',
#    'type': 'tree',
#    'sha': '2945e51c87ad5da893c954afcf092f06343bbb7d',
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/2945e51c87ad5da893c954afcf092f06343bbb7d'},
#   {'path': '15024/.0006.scavengerhunt',
#    'mode': '100644',
#    'type': 'blob',
#    'sha': '1c9064284a24b3486015eafdb391b141c27ada2b',
#    'size': 3,
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b'},
# ...

# %%
jokes1 = pd.DataFrame(jokes)
jokes1
# Out:
#                                           sha  \
# 0    9308ccc8a4c34c5e3a991ee815222a9691c32476
# 1    9308ccc8a4c34c5e3a991ee815222a9691c32476
# 2    9308ccc8a4c34c5e3a991ee815222a9691c32476
# 3    9308ccc8a4c34c5e3a991ee815222a9691c32476
# 4    9308ccc8a4c34c5e3a991ee815222a9691c32476
# 5    9308ccc8a4c34c5e3a991ee815222a9691c32476
# 6    9308ccc8a4c34c5e3a991ee815222a9691c32476
# 7    9308ccc8a4c34c5e3a991ee815222a9691c32476
# 8    9308ccc8a4c34c5e3a991ee815222a9691c32476
# 9    9308ccc8a4c34c5e3a991ee815222a9691c32476
# 10   9308ccc8a4c34c5e3a991ee815222a9691c32476
# 11   9308ccc8a4c34c5e3a991ee815222a9691c32476
# 12   9308ccc8a4c34c5e3a991ee815222a9691c32476
# 13   9308ccc8a4c34c5e3a991ee815222a9691c32476
# 14   9308ccc8a4c34c5e3a991ee815222a9691c32476
# 15   9308ccc8a4c34c5e3a991ee815222a9691c32476
# 16   9308ccc8a4c34c5e3a991ee815222a9691c32476
# 17   9308ccc8a4c34c5e3a991ee815222a9691c32476
# 18   9308ccc8a4c34c5e3a991ee815222a9691c32476
# ...

# %%
jokes1
# Out:
#                                           sha  \
# 0    9308ccc8a4c34c5e3a991ee815222a9691c32476
# 1    9308ccc8a4c34c5e3a991ee815222a9691c32476
# 2    9308ccc8a4c34c5e3a991ee815222a9691c32476
# 3    9308ccc8a4c34c5e3a991ee815222a9691c32476
# 4    9308ccc8a4c34c5e3a991ee815222a9691c32476
# 5    9308ccc8a4c34c5e3a991ee815222a9691c32476
# 6    9308ccc8a4c34c5e3a991ee815222a9691c32476
# 7    9308ccc8a4c34c5e3a991ee815222a9691c32476
# 8    9308ccc8a4c34c5e3a991ee815222a9691c32476
# 9    9308ccc8a4c34c5e3a991ee815222a9691c32476
# 10   9308ccc8a4c34c5e3a991ee815222a9691c32476
# 11   9308ccc8a4c34c5e3a991ee815222a9691c32476
# 12   9308ccc8a4c34c5e3a991ee815222a9691c32476
# 13   9308ccc8a4c34c5e3a991ee815222a9691c32476
# 14   9308ccc8a4c34c5e3a991ee815222a9691c32476
# 15   9308ccc8a4c34c5e3a991ee815222a9691c32476
# 16   9308ccc8a4c34c5e3a991ee815222a9691c32476
# 17   9308ccc8a4c34c5e3a991ee815222a9691c32476
# 18   9308ccc8a4c34c5e3a991ee815222a9691c32476
# ...

# %%
jokes1 = json_normalize(jokes, "tree")

# %%
jokes1
# Out:
#        mode                       path  \
# 0    100644                 .gitignore
# 1    040000                      15024
# 2    100644  15024/.0006.scavengerhunt
# 3    100644                   15024/40
# 4    100644                   15024/74
# 5    100644                   15024/99
# 6    040000                      15534
# 7    100644  15534/.0008.scavengerhunt
# 8    100644  15534/.0012.scavengerhunt
# 9    100644                    15534/2
# 10   100644                   15534/98
# 11   040000                      17020
# 12   100644  17020/.0007.scavengerhunt
# 13   100644                   17020/46
# 14   100644                   17020/97
# 15   040000                      30351
# 16   100644  30351/.0021.scavengerhunt
# 17   100644                   30351/22
# 18   100644                   30351/96
# 19   040000                      40303
# 20   100644  40303/.0022.scavengerhunt
# 21   100644                   40303/51
# 22   100644                   40303/65
# ...

# %%
jokes2 = jokes1['path']
jokes2
# Out:
# 0                     .gitignore
# 1                          15024
# 2      15024/.0006.scavengerhunt
# 3                       15024/40
# 4                       15024/74
# 5                       15024/99
# 6                          15534
# 7      15534/.0008.scavengerhunt
# 8      15534/.0012.scavengerhunt
# 9                        15534/2
# 10                      15534/98
# 11                         17020
# 12     17020/.0007.scavengerhunt
# 13                      17020/46
# 14                      17020/97
# 15                         30351
# 16     30351/.0021.scavengerhunt
# 17                      30351/22
# 18                      30351/96
# 19                         40303
# 20     40303/.0022.scavengerhunt
# 21                      40303/51
# 22                      40303/65
# 23                         44639
# 24     44639/.0005.scavengerhunt
# 25                      44639/76
# 26                      44639/91
# 27                         45525
# ...

# %%
for x, y in enumerate(jokes1["path"]):
    if "scavengerhunt" not in y:
        jokes1 = jokes1.drop([x])
jokes1
# Out:
#        mode                       path  \
# 2    100644  15024/.0006.scavengerhunt
# 7    100644  15534/.0008.scavengerhunt
# 8    100644  15534/.0012.scavengerhunt
# 12   100644  17020/.0007.scavengerhunt
# 16   100644  30351/.0021.scavengerhunt
# 20   100644  40303/.0022.scavengerhunt
# 24   100644  44639/.0005.scavengerhunt
# 28   100644  45525/.0018.scavengerhunt
# 32   100644  47222/.0016.scavengerhunt
# 33   100644  47222/.0024.scavengerhunt
# 37   100644  47830/.0010.scavengerhunt
# 41   100644  49418/.0014.scavengerhunt
# 46   100644  50896/.0011.scavengerhunt
# 50   100644  55417/.0023.scavengerhunt
# 54   100644  55685/.0020.scavengerhunt
# 58   100644  60224/.0003.scavengerhunt
# 70   100644  68848/.0004.scavengerhunt
# 74   100644  70751/.0019.scavengerhunt
# 79   100644  70985/.0017.scavengerhunt
# 83   100644  88596/.0002.scavengerhunt
# 92   100644  89338/.0013.scavengerhunt
# 97   100644  91701/.0015.scavengerhunt
# 101  100644  97881/.0009.scavengerhunt
# ...

# %%
urljokes = list(jokes1["url"])
urljokes
# Out:
# ['https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e351fb73264581ce26504b97ef07daea35116f32',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/209e3ef4b6247ce746048d5711befda46206d235',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/6abb415e0ae3450be0f323113bcca2af195ebbff',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/fb828e4a926b0a84fc16111fc0ee3eeec41f0ce7',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/bf3efa02f721c40c03a613824e345243a35f6812',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/3aaf448b40f878cf3067e2323616143bdde600de',
#  'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/397b22b2dc371e8db59ed327f0b75321e4c0d0f2',
# ...

# %%
listafinal = []
for x in range(1, 6):
    scavan = requests.get(urljokes[x])
    listafinal.append(scavan)
#var = scavan.get("content")

# %%
listafinal
# Out:
# [<Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>]

# %%
listadic = []
for x in listafinal:
    y = x.json()
    listadic.append(y)

# %%
listadic
# Out:
# [{'sha': 'e351fb73264581ce26504b97ef07daea35116f32',
#   'node_id': 'MDQ6QmxvYjE2MjM3NTE4MTplMzUxZmI3MzI2NDU4MWNlMjY1MDRiOTdlZjA3ZGFlYTM1MTE2ZjMy',
#   'size': 6,
#   'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e351fb73264581ce26504b97ef07daea35116f32',
#   'content': 'c3BlbnQK\n',
#   'encoding': 'base64'},
#  {'sha': '209e3ef4b6247ce746048d5711befda46206d235',
#   'node_id': 'MDQ6QmxvYjE2MjM3NTE4MToyMDllM2VmNGI2MjQ3Y2U3NDYwNDhkNTcxMWJlZmRhNDYyMDZkMjM1',
#   'size': 3,
#   'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/209e3ef4b6247ce746048d5711befda46206d235',
#   'content': 'MjAK\n',
#   'encoding': 'base64'},
#  {'sha': '6abb415e0ae3450be0f323113bcca2af195ebbff',
#   'node_id': 'MDQ6QmxvYjE2MjM3NTE4MTo2YWJiNDE1ZTBhZTM0NTBiZTBmMzIzMTEzYmNjYTJhZjE5NWViYmZm',
#   'size': 5,
#   'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/6abb415e0ae3450be0f323113bcca2af195ebbff',
#   'content': 'dGltZQo=\n',
# ...

# %%
listadic[0].get("content")
# Out:
# 'c3BlbnQK\n'

# %%
listadecod = []
for x in listadic:
        z = x.get("content")
        listadecod.append(z)
listadecod
# Out:
# ['c3BlbnQK\n', 'MjAK\n', 'dGltZQo=\n', 'bmVlZAo=\n', 'dG8K\n']

# %%
import base64
palabras = []
for x in listadecod:
    dec = base64.b64decode(x)
    palabras.append(dec)
palabras
# Out:
# [b'spent\n', b'20\n', b'time\n', b'need\n', b'to\n']
