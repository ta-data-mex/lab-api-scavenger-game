# %%
# enter your code below
import json 
import pandas as pd 
import requests
from pandas.io.json import json_normalize
#forks
url='https://api.github.com/repos/ta-data-mex/lab-api-scavenger-game/forks'
response=requests.get(url)
results=response.json()
#print(results)
data=json_normalize(results)
data
# Out:
#            id                           node_id                    name  \
# 0   219392195  MDEwOlJlcG9zaXRvcnkyMTkzOTIxOTU=  lab-api-scavenger-game
# 1   219091936  MDEwOlJlcG9zaXRvcnkyMTkwOTE5MzY=  lab-api-scavenger-game
# 2   218176289  MDEwOlJlcG9zaXRvcnkyMTgxNzYyODk=  lab-api-scavenger-game
# 3   218173574  MDEwOlJlcG9zaXRvcnkyMTgxNzM1NzQ=  lab-api-scavenger-game
# 4   218163890  MDEwOlJlcG9zaXRvcnkyMTgxNjM4OTA=  lab-api-scavenger-game
# 5   218159629  MDEwOlJlcG9zaXRvcnkyMTgxNTk2Mjk=  lab-api-scavenger-game
# 6   217952713  MDEwOlJlcG9zaXRvcnkyMTc5NTI3MTM=  lab-api-scavenger-game
# 7   217775551  MDEwOlJlcG9zaXRvcnkyMTc3NzU1NTE=  lab-api-scavenger-game
# 8   216688696  MDEwOlJlcG9zaXRvcnkyMTY2ODg2OTY=  lab-api-scavenger-game
# 9   197312661  MDEwOlJlcG9zaXRvcnkxOTczMTI2NjE=  lab-api-scavenger-game
# 10  197246038  MDEwOlJlcG9zaXRvcnkxOTcyNDYwMzg=  lab-api-scavenger-game
# 11  197107749  MDEwOlJlcG9zaXRvcnkxOTcxMDc3NDk=  lab-api-scavenger-game
# ...

# %%
#languages
url='https://api.github.com/users/ta-data-mex/repos'
response=requests.get(url)
results=response.json()
data=json_normalize(results)
data
# Out:
#            id                           node_id  \
# 0   194741141  MDEwOlJlcG9zaXRvcnkxOTQ3NDExNDE=
# 1   193751809  MDEwOlJlcG9zaXRvcnkxOTM3NTE4MDk=
# 2   197823599  MDEwOlJlcG9zaXRvcnkxOTc4MjM1OTk=
# 3   193749663  MDEwOlJlcG9zaXRvcnkxOTM3NDk2NjM=
# 4   193753617  MDEwOlJlcG9zaXRvcnkxOTM3NTM2MTc=
# 5   193753215  MDEwOlJlcG9zaXRvcnkxOTM3NTMyMTU=
# 6   199402640  MDEwOlJlcG9zaXRvcnkxOTk0MDI2NDA=
# 7   200599800  MDEwOlJlcG9zaXRvcnkyMDA1OTk4MDA=
# 8   193754942  MDEwOlJlcG9zaXRvcnkxOTM3NTQ5NDI=
# 9   199395137  MDEwOlJlcG9zaXRvcnkxOTkzOTUxMzc=
# 10  199400669  MDEwOlJlcG9zaXRvcnkxOTk0MDA2Njk=
# 11  193752780  MDEwOlJlcG9zaXRvcnkxOTM3NTI3ODA=
# 12  195840596  MDEwOlJlcG9zaXRvcnkxOTU4NDA1OTY=
# 13  195843084  MDEwOlJlcG9zaXRvcnkxOTU4NDMwODQ=
# 14  198136340  MDEwOlJlcG9zaXRvcnkxOTgxMzYzNDA=
# 15  199396153  MDEwOlJlcG9zaXRvcnkxOTkzOTYxNTM=
# 16  193750493  MDEwOlJlcG9zaXRvcnkxOTM3NTA0OTM=
# 17  193750192  MDEwOlJlcG9zaXRvcnkxOTM3NTAxOTI=
# ...

# %%
#seleccionando las columnas 
import numpy as np
select_columns=['name','language']
print(data[select_columns])
#con iteración
data2=data[select_columns].to_string(index=False)
#print(np.array(data2))
# Out:
#                                        name          language
# 0                              intro-to-git              None
# 1                        lab-advanced-mysql              None
# 2                       lab-advanced-pandas  Jupyter Notebook
# 3                        lab-advanced-regex  Jupyter Notebook
# 4                 lab-advanced-web-scraping  Jupyter Notebook
# 5                    lab-api-scavenger-game            Python
# 6                   lab-bayesian-statistics  Jupyter Notebook
# 7              lab-bi-analysis-with-tableau              None
# 8            lab-code-simplicity-efficiency            Python
# 9   lab-continuous-probability-distribution  Jupyter Notebook
# 10         lab-correlation-tests-with-scipy  Jupyter Notebook
# 11                        lab-data-cleaning  Jupyter Notebook
# 12                         lab-data-vikings            Python
# 13                       lab-data-vikings-1            Python
# ...
