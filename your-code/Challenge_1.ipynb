# %%
import requests 
import pandas as pd
from pandas.io.json import json_normalize

# %%
git_forks = requests.get("https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/forks")
git_languages = requests.get("https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/languages")
git_commits = requests.get("https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/commits")

# %%
git_forks = git_forks.json()
git_languages = git_languages.json()
git_commits = git_commits.json()

from collections import Counter



Counter(git_commits).keys() # equals to list(set(words))
Counter(git_commits).values() # counts the elements' frequency
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-8196849fea15> in <module>
# ----> 1 git_forks = git_forks.json()
#       2 git_languages = git_languages.json()
#       3 git_commits = git_commits.json()
#       4
#       5 from collections import Counter
#
# AttributeError: 'list' object has no attribute 'json'

# %%
git_languages
list(git_languages)
# Out:
# ['Jupyter Notebook', 'HTML', 'Python']

# %%
git_commits = pd.DataFrame(git_commits)

# %%
git_commits
# Out:
#                                                author  \
# 0   {'login': 'ta-data-bcn', 'id': 47005065, 'node...
# 1   {'login': 'ta-data-bcn', 'id': 47005065, 'node...
# 2   {'login': 'ojedatony1616', 'id': 1253136, 'nod...
# 3   {'login': 'michalmonselise', 'id': 7342857, 'n...
# 4   {'login': 'michalmonselise', 'id': 7342857, 'n...
# 5   {'login': 'michalmonselise', 'id': 7342857, 'n...
# 6   {'login': 'michalmonselise', 'id': 7342857, 'n...
# 7   {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 8   {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 9   {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 10  {'login': 'michalmonselise', 'id': 7342857, 'n...
# 11  {'login': 'michalmonselise', 'id': 7342857, 'n...
# 12  {'login': 'michalmonselise', 'id': 7342857, 'n...
# 13  {'login': 'michalmonselise', 'id': 7342857, 'n...
# 14  {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 15  {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# ...
